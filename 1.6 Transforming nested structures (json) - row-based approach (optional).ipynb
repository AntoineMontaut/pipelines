# %% [markdown]
# Sometimes your input data can be nested with more difficult structure than a simple table or a matrix.
#
# In such cases it is sometime useful to shift mental orientation to analyze and extract information froms rows rather then non-defined columns.

# %%
from utils import css_from_file
css_from_file('style/style.css')
# Out:
# <style>/*@font-face {
# 	font-family: "Computer Modern";
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-weight: bold;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-style: oblique;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
# }
# @font-face {
# 	font-family: "Computer Modern";
# 	font-weight: bold;
# 	font-style: oblique;
# 	src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
# }*/
#
# .navbar-brand, .current_kernel_logo {display:none}
# .container {
#     width:80%;
# }
#
# h1 {
# 	font-family: Helvetica, serif;
# }
# h4{
# 	margin-top:12px;
# 	margin-bottom: 3px;
#    }
# div.text_cell_render{
# 	font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
# 	line-height: 145%;
# 	font-size: 100%;
# 	width:100%;
# 	margin-left:auto;
# 	margin-right:auto;
# }
# .CodeMirror{
# 		font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
# }
# .text_cell_render h5 {
# 	font-weight: 300;
# 	font-size: 22pt;
# 	/*color: #4057A1;*/
# 	font-style: italic;
# 	margin-bottom: .5em;
# 	margin-top: 0.5em;
# 	display: block;
# }
#
# .warning{
# 	color: rgb( 240, 20, 20 )
# 	}
#
# div.spoiler {
# 	display: none;
# }
#
# .rendered_html code {
# 	border: 0;
# 	/*background-color: #eee;*/
# 	font-size: 100%;
# 	padding: 1px 2px;
# }
# </style>

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\antoine\anaconda3\lib\site-packages
# Requirement already satisfied: six in c:\users\antoine\anaconda3\lib\site-packages (from nltk)

# %%
import json
import numpy as np
import pprint
from nltk import download, word_tokenize

download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Antoine\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
with open("data/companies/companies.json", encoding='utf-8') as dataf:
    data = [json.loads(line) for line in dataf]
#     for line in dataf:
#         try:
#             json.loads(line)
#         except:
#             print(line)
#             break

# %% [markdown]
# An example of deeply nested data with various data types:
#
# Exercise:
#
# 1. Name variable types
# 2. What do you do with lists, geo location?
# 3. What do you do with counts?

# %%
pprint.pprint(data[3])
# Out:
# {'address': {'city': 'Düsseldorf',
#              'country': 'Germany',
#              'postalCode': '40221',
#              'raw': 'Speditionstr. 15a\n\nDüsseldorf,\nNRW\n40221\nGermany',
#              'region': 'NRW',
#              'street': 'Speditionstr. 15a'},
#  'description': '1stMOVER is a startup incubator & enterprise consultancy for '
#                 'new digital business. We support startups and enterprises '
#                 'with specialised incubation & consulting services. For '
#                 'Startups: - Seed funding (100k€ + co-investors) - Support of '
#                 'business model & product design - Operational incubation '
#                 'support - Initiation of enterprise co-operations - Finding '
#                 'strategic investors For Enterprises: - Development & '
#                 'implementation of models for successful startup co-operations '
#                 '- Building up bootcamp, acceleration & incubation programmes '
#                 'with startups - Development of platform & portfolio '
#                 'strategies - M&A support for target selection, due diligence '
#                 'and integration planning - Innovation audits for strategies, '
#                 'portfolios and processes We are an experienced team of '
#                 'experts for digital business & products, cooperating with a '
#                 'network of dedicated on-demand specialists. Since 2009 we '
#                 'have been building up special competencies on the interface '
#                 'between digital startups and enterprises.',
#  'domain': '1stmover.org',
#  'extension': {'address': 'Düsseldorf Area, Germany',
#                'geo_location': {'country': 'Europe',
#                                 'formatted_address': 'Germany, Europe',
#                                 'location': [51.0834196, 10.4234469],
#                                 'raw': 'Düsseldorf Area, Germany',
#                                 'timezone': 'Europe/Berlin'},
#                'geo_location_triple': {'administrative_area': 'North '
#                                                               'Rhine-Westphalia',
#                                        'city': 'Düsseldorf',
#                                        'country': 'Germany'},
#                'industries': [{'count': 2,
#                                'industry': 'Venture Capital & Private Equity'},
#                               {'count': 1, 'industry': 'Internet'}],
#                'job_positions': [{'count': 1,
#                                   'job_position': 'Founder/Managing Director'},
#                                  {'count': 1,
#                                   'job_position': 'Partner, Investment '
#                                                   'Manager'},
#                                  {'count': 1, 'job_position': 'Partner'}],
#                'name': '1stMOVER',
#                'persons_in_database': 3,
#                'skills': [{'count': 3, 'skill': 'Strategy'},
#                           {'count': 3, 'skill': 'Mobile Communications'},
#                           {'count': 3, 'skill': 'Mobile Devices'},
#                           {'count': 2, 'skill': 'Management'},
#                           {'count': 2, 'skill': 'Business Modeling'},
#                           {'count': 2, 'skill': 'E-commerce'},
#                           {'count': 2, 'skill': 'Mobile Applications'},
#                           {'count': 2, 'skill': 'Start-ups'},
#                           {'count': 2, 'skill': 'Mobilanwendungen'},
#                           {'count': 2, 'skill': 'Mobile Internet'},
#                           {'count': 2, 'skill': 'Wireless'},
#                           {'count': 2, 'skill': 'Strategisches Management'},
#                           {'count': 2, 'skill': 'Telecommunications'},
#                           {'count': 2, 'skill': 'Mobiltechnologie'},
#                           {'count': 2, 'skill': 'GSM'},
#                           {'count': 2, 'skill': 'Strategische Partnerschaften'},
#                           {'count': 2, 'skill': 'Mobile Technology'},
#                           {'count': 2, 'skill': 'Strategic Partnerships'},
#                           {'count': 2, 'skill': 'Mobile Geräte'},
#                           {'count': 2, 'skill': 'E-Commerce'},
#                           {'count': 1, 'skill': 'Cellular Communications'},
#                           {'count': 1, 'skill': 'Department Management'},
#                           {'count': 1, 'skill': 'TCP/IP'},
#                           {'count': 1, 'skill': 'Mobile Advertising'},
#                           {'count': 1, 'skill': 'UMTS'},
#                           {'count': 1, 'skill': 'Coaching'},
#                           {'count': 1, 'skill': 'Personnel Management'},
#                           {'count': 1, 'skill': 'ATM networks'},
#                           {'count': 1, 'skill': 'IP'},
#                           {'count': 1, 'skill': 'Mobile Commerce'},
#                           {'count': 1, 'skill': 'WCDMA'},
#                           {'count': 1, 'skill': 'Produktmarketing'},
#                           {'count': 1, 'skill': 'Project Management'},
#                           {'count': 1, 'skill': 'Early-stage Startups'},
#                           {'count': 1, 'skill': 'Mobile Content'},
#                           {'count': 1, 'skill': 'Risikokapital'},
#                           {'count': 1, 'skill': 'Mobiles Internet'},
#                           {'count': 1, 'skill': 'Product Marketing'},
#                           {'count': 1, 'skill': 'VAS'},
#                           {'count': 1, 'skill': 'RAN'},
#                           {'count': 1, 'skill': 'Mobile Marketing'},
#                           {'count': 1, 'skill': 'Cloud-Computing'},
#                           {'count': 1, 'skill': 'Business Development'},
#                           {'count': 1, 'skill': 'Product Development'},
#                           {'count': 1, 'skill': 'Go-to-market Strategy'},
#                           {'count': 1, 'skill': 'Outsourcing'},
#                           {'count': 1, 'skill': 'LTE'},
#                           {'count': 1, 'skill': 'Marketing Strategy'},
#                           {'count': 1, 'skill': 'MVP'},
#                           {'count': 1, 'skill': 'Consulting'},
#                           {'count': 1, 'skill': 'Mehrwertdienste'},
#                           {'count': 1, 'skill': 'Unternehmensberatung'},
#                           {'count': 1, 'skill': 'Mobile Kommunikation'},
#                           {'count': 1, 'skill': 'Marketingstrategie'},
#                           {'count': 1, 'skill': 'Quality Management'},
#                           {'count': 1, 'skill': 'Incubation'},
#                           {'count': 1, 'skill': 'Telco'},
#                           {'count': 1, 'skill': 'Organizational Development'},
#                           {'count': 1, 'skill': 'Unternehmensstrategie'},
#                           {'count': 1, 'skill': 'Agile Methodologies'},
#                           {'count': 1, 'skill': 'Embedded Software'},
#                           {'count': 1, 'skill': 'Funkverkehr'},
#                           {'count': 1, 'skill': 'Entrepreneurship'},
#                           {'count': 1, 'skill': 'Location Based Services'},
#                           {'count': 1, 'skill': 'Business Strategy'},
#                           {'count': 1, 'skill': '2G'},
#                           {'count': 1, 'skill': 'Planning'},
#                           {'count': 1, 'skill': 'Testing'},
#                           {'count': 1, 'skill': 'Go-to-Market'},
#                           {'count': 1, 'skill': 'SMS'},
#                           {'count': 1, 'skill': 'Lean Startup'},
#                           {'count': 1, 'skill': 'Mobile Strategy'},
#                           {'count': 1, 'skill': 'Integration'},
#                           {'count': 1, 'skill': 'Restructuring'},
#                           {'count': 1, 'skill': 'Project Planning'},
#                           {'count': 1, 'skill': '3G'},
#                           {'count': 1, 'skill': 'Resource Management'},
#                           {'count': 1, 'skill': 'Network Design'},
#                           {'count': 1, 'skill': 'Embedded Systems'},
#                           {'count': 1, 'skill': 'Mobiles Marketing'},
#                           {'count': 1, 'skill': 'Product Management'},
#                           {'count': 1, 'skill': 'R&D'},
#                           {'count': 1, 'skill': 'Produktmanagement'},
#                           {'count': 1, 'skill': 'Start-up Consulting'},
#                           {'count': 1, 'skill': '4G'},
#                           {'count': 1, 'skill': 'Management Consulting'},
#                           {'count': 1, 'skill': 'Venture Capital'},
#                           {'count': 1, 'skill': 'Technology Incubation'},
#                           {'count': 1, 'skill': 'Unternehmertum'},
#                           {'count': 1, 'skill': 'Investment Advisory'},
#                           {'count': 1, 'skill': 'Cloud Computing'},
#                           {'count': 1, 'skill': 'Change Management'},
#                           {'count': 1, 'skill': 'Leadership Development'},
#                           {'count': 1, 'skill': 'Line Management'},
#                           {'count': 1, 'skill': 'Telekommunikation'},
#                           {'count': 1, 'skill': 'Financial Planning'},
#                           {'count': 1, 'skill': 'Leadership'},
#                           {'count': 1, 'skill': 'Solutions Marketing'},
#                           {'count': 1, 'skill': 'SDH'},
#                           {'count': 1, 'skill': 'Mobile Payments'},
#                           {'count': 1, 'skill': 'Transmission Systems'},
#                           {'count': 1, 'skill': 'Open Source Software'},
#                           {'count': 1, 'skill': 'Unternehmensführung'}],
#                'url': 'linkedin.com/company/1stmover'},
#  'founded_year': 2009,
#  'industries': ['Internet'],
#  'metadata': {'documents': [{'ids': ['b28ccc5d298c56b98bbcdeafdcb6f938'],
#                              'path': 'linkedin'},
#                             {'ids': ['7807ba43552e596a8a724085b2e79e87'],
#                              'path': 'built_with'},
#                             {'ids': ['a88b0dae27cb5f32b99e32c6c7b516e9'],
#                              'path': 'wappalyzer'}],
#               'urls': []},
#  'name': '1stMOVER Management , 1stMOVER Beteiligungen & Co. KG',
#  'public_url': 'http://www.linkedin.com/company/1088641',
#  'raw_text': '1stMOVER is a startup incubator & enterprise consultancy for new '
#              'digital business. We support startups and enterprises with '
#              'specialised incubation & consulting services. For Startups: - '
#              'Seed funding (100k€ + co-investors) - Support of business model '
#              '& product design - Operational incubation support - Initiation '
#              'of enterprise co-operations - Finding strategic investors For '
#              'Enterprises: - Development & implementation of models for '
#              'successful startup co-operations - Building up bootcamp, '
#              'acceleration & incubation programmes with startups - Development '
#              'of platform & portfolio strategies - M&A support for target '
#              'selection, due diligence and integration planning - Innovation '
#              'audits for strategies, portfolios and processes We are an '
#              'experienced team of experts for digital business & products, '
#              'cooperating with a network of dedicated on-demand specialists. '
#              'Since 2009 we have been building up special competencies on the '
#              'interface between digital startups and enterprises.',
#  'size_begin': 1,
#  'size_end': 10,
#  'specialties': ['Startup Incubation',
#                  'New Digital Business',
#                  'Acceleration & Incubation Programmes',
#                  'M&A Support',
#                  'Platform & Portfolio Strategies'],
#  'technologies': ['Apache',
#                   'Google Analytics',
#                   'UTF-8',
#                   'HTML5 DocType',
#                   'Cascading Style Sheets',
#                   'Apache 2.2',
#                   'Google Analytics Classic',
#                   'skelJS',
#                   'Unix',
#                   'Meta Robot',
#                   'HTML 5 Specific Tags',
#                   'jQuery',
#                   'Conditional Comments',
#                   'Javascript',
#                   'Google Font API',
#                   'Font Awesome',
#                   'Google Analytics Anonymize IP',
#                   'PHP',
#                   'Canonical Content Tag',
#                   'Euro',
#                   'UNIX',
#                   'Meta Description'],
#  'uuid': 'b28ccc5d298c56b98bbcdeafdcb6f938',
#  'website': 'http://www.1stmover.org'}

# %% [markdown]
# Exercise
# --------------
#
# Write a pipeline to transform company records.
# 1. Select 3 types of features you want to transform (like descrpition, list of skills, technologies, address etc)
# 2. Create a pipeline in this format:
# ```python
# make_union(
#     make_pipeline(TechnologyFeatures(), DictVectorizer()),
#     make_pipeline(AddressFeatures(), DictVectorizer()),
#     make_pipeline(ExtractDescription(), CountVectorizer())
# )
# ```
# 3. Classify industry (like in the previous exercise)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import make_pipeline, make_union
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier

# %%
class TechnologyFeatures(BaseEstimator, TransformerMixin):

    def __init__(self):
        pass

    def fit(self, x, y = None):
        return self

    def transform(self, x):
        technologies = []
        # row.get('technologies', [])
        for company in x:
            techs = {}
            company_techs = company.get('technologies', [])
            for tech in company_techs:
                techs[tech] = 1
            technologies.append(techs)
        return technologies
    
    
class AddressFeatures(BaseEstimator, TransformerMixin):
    
    def __init__(self):
        pass
    
    def fit(self, x, y=None):
        return self
    
    def transform(self, x):
        addresses = []
        for company in x:
#             country = company.get('address', {}).get('country','')
#             if country == '':
#                 country = company.get('extension',{}).get('geo_location',{}).get('country','')
#             if country == '':
#                 country = company.get('extension',{}).get('geo_location_triple',{}).get('country','')
                
            country = (
                company.get('address', {}).get('country', None)
                or
                company.get('extension',{}).get('geo_location',{}).get('country', None)
                or
                company.get('extension',{}).get('geo_location_triple',{}).get('country', '')
            )
            
#             city = company.get('address', {}).get('city', '')
#             if city == '':
#                 city = company.get('extension',{}).get('geo_location',{}).get('city','')
#             if city == '':
#                 city = company.get('extension',{}).get('geo_location_triple',{}).get('city','')
            city = (
                company.get('address', {}).get('city', None)
                or
                company.get('extension',{}).get('geo_location',{}).get('city', None)
                or
                company.get('extension',{}).get('geo_location_triple',{}).get('city', '')
            )
                
            addresses.append({'country': country, 'city':city})
        return addresses
    

class ExtractDescription():
    def __init__(self):
        pass
    
    def fit(self, x, y=None):
        return self
    
    def transform(self, x):
        descriptions = []
        for company in x:
            descriptions.append(company.get('description', ''))
        
        return descriptions
    
class ExtractIndustry():
    def __init__(self):
        pass
    
    def fit(self, x, y=None):
        return self
    
    def transform(self, x):
        industries_list = []
        for company in x:
            industries = company.get('industries', [])
            if industries:
                industries_list.append(industries[0])
            else:
                industries_list.append('unknown')
        return industries_list
    
# tech_feat = TechnologyFeatures()
# tech_feat.transform(data)
# address_feat = AddressFeatures()
# address_feat.transform(data)
# descriptions_feat = ExtractDescription()
# descriptions_feat.transform(data)
# industries = ExtractIndustry()
# industries.transform(data)

# %%
extract_industries = ExtractIndustry()
Y = extract_industries.transform(data)

pipe = make_pipeline(
    make_union(
        make_pipeline(TechnologyFeatures(), DictVectorizer()),
        make_pipeline(AddressFeatures(), DictVectorizer()),
        make_pipeline(ExtractDescription(), CountVectorizer())
    ),
    StandardScaler(with_mean=False, with_std=False),
    SGDClassifier(alpha=0.01)
)

pipe.fit(data[:8000], Y[:8000])

y_pred = pipe.predict(data[8000:])
print(classification_report(Y[8000:], y_pred))
# Out:
# C:\Users\Antoine\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
#                                       precision    recall  f1-score   support
#
#                           Accounting       0.50      0.47      0.49        19
#                    Airlines/Aviation       0.00      0.00      0.00        10
#                 Alternative Medicine       0.00      0.00      0.00         2
#                            Animation       0.00      0.00      0.00         2
#                    Apparel & Fashion       0.27      0.23      0.25        13
#              Architecture & Planning       0.50      0.46      0.48        28
#                      Arts and Crafts       0.00      0.00      0.00        11
#                           Automotive       0.50      0.59      0.54        32
#                 Aviation & Aerospace       0.00      0.00      0.00         6
#                              Banking       0.33      0.20      0.25         5
#                        Biotechnology       0.40      0.22      0.29         9
#                      Broadcast Media       0.00      0.00      0.00         5
#                   Building Materials       0.00      0.00      0.00         6
#      Business Supplies and Equipment       0.33      0.09      0.14        11
#                      Capital Markets       0.00      0.00      0.00         1
#                            Chemicals       0.17      0.20      0.18         5
#          Civic & Social Organization       0.50      0.10      0.17        10
#                    Civil Engineering       0.29      0.31      0.30        13
#               Commercial Real Estate       0.00      0.00      0.00         2
#          Computer & Network Security       0.00      0.00      0.00         4
#                       Computer Games       0.40      0.33      0.36         6
#                    Computer Hardware       0.00      0.00      0.00         4
#                  Computer Networking       0.00      0.00      0.00         4
#                    Computer Software       0.24      0.35      0.28        57
#                         Construction       0.33      0.39      0.36        66
#                 Consumer Electronics       0.00      0.00      0.00         5
#                       Consumer Goods       0.00      0.00      0.00        17
#                    Consumer Services       0.16      0.29      0.21        14
#                            Cosmetics       0.00      0.00      0.00         4
#                                Dairy       0.00      0.00      0.00         1
#                      Defense & Space       0.00      0.00      0.00         3
#                               Design       0.26      0.36      0.30        45
#                           E-Learning       0.00      0.00      0.00         6
#                 Education Management       0.29      0.68      0.40        34
#  Electrical/Electronic Manufacturing       0.56      0.38      0.45        24
#                        Entertainment       0.22      0.09      0.13        22
#               Environmental Services       0.57      0.24      0.33        17
#                      Events Services       0.57      0.43      0.49        28
#                     Executive Office       0.00      0.00      0.00         1
#                  Facilities Services       0.00      0.00      0.00        10
#                              Farming       0.00      0.00      0.00         5
#                   Financial Services       0.33      0.45      0.38        49
#                             Fine Art       0.25      0.14      0.18         7
#                              Fishery       0.00      0.00      0.00         2
#                     Food & Beverages       0.00      0.00      0.00        24
#                      Food Production       0.00      0.00      0.00        11
#                         Fund-Raising       0.00      0.00      0.00         3
#                            Furniture       0.60      0.50      0.55         6
#                   Gambling & Casinos       0.00      0.00      0.00         4
#            Government Administration       0.00      0.00      0.00         7
#                 Government Relations       0.00      0.00      0.00         1
#                       Graphic Design       0.00      0.00      0.00        18
#         Health, Wellness and Fitness       0.21      0.47      0.29        38
#                     Higher Education       0.00      0.00      0.00         6
#               Hospital & Health Care       0.59      0.42      0.49        31
#                          Hospitality       0.43      0.14      0.21        22
#                      Human Resources       0.22      0.44      0.30        18
#                    Import and Export       0.00      0.00      0.00         6
#         Individual & Family Services       0.00      0.00      0.00        11
#                Industrial Automation       0.00      0.00      0.00         6
#                 Information Services       0.00      0.00      0.00         9
#  Information Technology and Services       0.40      0.40      0.40       156
#                                 Inne       0.00      0.00      0.00         0
#                            Insurance       0.67      0.67      0.67        27
#                International Affairs       0.00      0.00      0.00         2
#  International Trade and Development       0.00      0.00      0.00         6
#                             Internet       0.18      0.21      0.19        73
#                   Investment Banking       0.00      0.00      0.00         2
#                Investment Management       0.00      0.00      0.00        11
#                      Law Enforcement       0.00      0.00      0.00         2
#                         Law Practice       0.90      0.61      0.73        31
#                       Legal Services       0.50      0.20      0.29        15
#            Leisure, Travel & Tourism       0.32      0.40      0.36        20
#                            Libraries       0.00      0.00      0.00         3
#           Logistics and Supply Chain       1.00      0.07      0.12        15
#               Luxury Goods & Jewelry       0.00      0.00      0.00         8
#                            Machinery       0.08      0.07      0.07        15
#                Management Consulting       0.18      0.43      0.25        44
#                             Maritime       0.00      0.00      0.00         9
#                      Market Research       0.00      0.00      0.00         1
#            Marketing and Advertising       0.30      0.77      0.43       108
# Mechanical or Industrial Engineering       0.75      0.17      0.27        18
#                     Media Production       0.40      0.20      0.27        20
#                      Medical Devices       0.40      0.20      0.27        10
#                     Medical Practice       0.27      0.67      0.39         9
#                             Medycyna       0.00      0.00      0.00         1
#                   Mental Health Care       0.00      0.00      0.00         7
#                      Mining & Metals       0.00      0.00      0.00         9
#             Motion Pictures and Film       1.00      0.11      0.20         9
#                                Music       0.40      0.18      0.25        11
#                           Newspapers       0.00      0.00      0.00         2
#    Nonprofit Organization Management       0.25      0.31      0.28        36
#                         Oil & Energy       0.17      0.11      0.13        19
#                         Online Media       0.00      0.00      0.00         7
#               Outsourcing/Offshoring       0.00      0.00      0.00         5
#             Package/Freight Delivery       0.00      0.00      0.00         2
#             Packaging and Containers       0.00      0.00      0.00         9
#              Paper & Forest Products       0.00      0.00      0.00         2
#                      Performing Arts       0.50      0.17      0.25         6
#                      Pharmaceuticals       0.29      0.15      0.20        13
#                         Philanthropy       0.00      0.00      0.00         5
#                          Photography       0.88      0.44      0.58        16
#                             Plastics       0.00      0.00      0.00         7
#               Political Organization       0.00      0.00      0.00         2
#          Primary/Secondary Education       0.67      0.29      0.40         7
#                             Printing       0.45      0.50      0.48        10
#                            Produkcja       0.25      0.50      0.33         2
#     Professional Training & Coaching       0.57      0.14      0.23        28
#                  Program Development       0.00      0.00      0.00         4
#                        Public Policy       0.00      0.00      0.00         2
#  Public Relations and Communications       0.00      0.00      0.00        10
#                        Public Safety       0.00      0.00      0.00         2
#                           Publishing       0.40      0.14      0.21        14
#                          Real Estate       0.31      0.80      0.44        45
# Recreational Facilities and Services       0.00      0.00      0.00         2
#               Religious Institutions       1.00      0.10      0.18        10
#             Renewables & Environment       0.50      0.46      0.48        13
#                             Research       0.20      0.06      0.09        18
#                          Restaurants       0.00      0.00      0.00         8
#                               Retail       0.13      0.14      0.14        29
#          Security and Investigations       0.40      0.22      0.29         9
#                       Semiconductors       0.00      0.00      0.00         1
#                         Shipbuilding       0.00      0.00      0.00         1
#                       Sporting Goods       0.00      0.00      0.00         5
#                               Sports       0.11      0.43      0.18        14
#              Staffing and Recruiting       0.64      0.44      0.52        32
#                   Telecommunications       0.20      0.25      0.22        16
#                             Textiles       0.00      0.00      0.00         8
#         Translation and Localization       1.00      0.40      0.57         5
#     Transportation/Trucking/Railroad       0.20      0.23      0.21        13
#                            Utilities       0.00      0.00      0.00         4
#     Venture Capital & Private Equity       0.00      0.00      0.00         7
#                           Veterinary       0.00      0.00      0.00         6
#                            Wholesale       0.00      0.00      0.00         6
#                     Wine and Spirits       0.00      0.00      0.00         8
#                             Wireless       0.00      0.00      0.00         3
#                  Writing and Editing       0.00      0.00      0.00         8
#                               Zakupy       0.00      0.00      0.00         1
#                              unknown       0.41      0.97      0.58        30
#
#                          avg / total       0.31      0.32      0.28      2000
# C:\Users\Antoine\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Antoine\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# Exercise
# ===============
#
# 1. Write a transformation class called SparsityFilter that accepts a minimum frequency. Watch out for fit function - this class has some state that you must save
#
# ```
# class SparsityFilter(BaseEstimator, TransformerMixin):
#     def __init__(self, min_nnz=None):
#         self.min_nnz = min_nnz
#
#     def fit(self, X, y=None):
#         ???
#         return self
#
#     def transform(self, X):
#         return ???
# ```

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction import DictVectorizer

# %%
class Sparsity(BaseEstimator, TransformerMixin):

    def __init__(self, min_nnz=None):
        min_nnz= min_nnz

    def fit(self, x, y = None):
        return self

    def transform(self, x):
        return x

# %% [markdown]
# Double click to see the solution
#
# <div class="spoiler">
#
# class SparsityFilter(BaseEstimator, TransformerMixin):
#     def __init__(self, min_nnz=None):
#         self.min_nnz = min_nnz
#
#     def fit(self, X, y=None):
#         self.sparsity = X.getnnz(0)
#         return self
#
#     def transform(self, X):
#         return X[:, self.sparsity >= self.min_nnz]
# </div>
